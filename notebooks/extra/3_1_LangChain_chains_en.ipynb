# %% [markdown]
# ## LangChain chains

# %%
# (setup cell already installs what this notebook needs)

# %% [markdown]
# ### Simple chain: prompt → model → result

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain_openai import ChatOpenAI
from dotenv import load_dotenv

load_dotenv()

prompt = ChatPromptTemplate.from_messages([
    ("system", "You are a Python programming expert and an AI genius."),
    ("user", "Write a code related to {topic}")
])

llm = ChatOpenAI(model="gpt-5.6-luna", temperature=0)

chain = prompt | llm | StrOutputParser()
result = chain.invoke({'topic': 'AGI'})

# %%
print(result)
# Out:
# Creating a full-fledged Artificial General Intelligence (AGI) is a highly complex and ambitious task that goes beyond a simple code snippet. However, I can provide you with a basic framework that simulates some aspects of AGI-like behavior using Python. This example will focus on a simple conversational agent that can learn from interactions, which is a small step towards more advanced AI systems.
#
# Here's a basic implementation of a conversational agent that uses a simple memory mechanism to learn from user inputs:
#
# ```python
# import random
#
# class SimpleAGI:
#     def __init__(self):
#         self.memory = {}
#
#     def learn(self, user_input):
#         # Split the input into words and store them in memory
#         words = user_input.lower().split()
#         for word in words:
#             if word in self.memory:
#                 self.memory[word] += 1
#             else:
#                 self.memory[word] = 1
#
#     def respond(self, user_input):
#         # Generate a response based on learned words
#         if user_input.lower() in self.memory:
#             return f"I remember you mentioned '{user_input}'. You seem to like it!"
#         else:
#             return "That's interesting! Tell me more."
#
#     def chat(self):
#         print("Hello! I'm a simple AGI. Let's chat! (type 'exit' to stop)")
#         while True:
#             user_input = input("You: ")
#             if user_input.lower() == 'exit':
#                 print("Goodbye!")
#                 break
#             self.learn(user_input)
#             response = self.respond(user_input)
#             print(f"AGI: {response}")
#
# if __name__ == "__main__":
#     agi = SimpleAGI()
#     agi.chat()
# ```
#
# ### Explanation:
# 1. **Class Definition**: The `SimpleAGI` class encapsulates the behavior of the conversational agent.
# 2. **Memory**: It uses a dictionary to store words and their frequencies, simulating a simple memory.
# 3. **Learning**: The `learn` method processes user input and updates the memory.
# 4. **Response Generation**: The `respond` method generates responses based on the learned words.
# 5. **Chat Loop**: The `chat` method allows for continuous interaction until the user types 'exit'.
#
# ### How to Run:
# 1. Copy the code into a Python environment (like Jupyter Notebook, PyCharm, or any Python IDE).
# 2. Run the script, and you can start chatting with the agent.
#
# ### Limitations:
# - This is a very simplistic model and does not represent true AGI.
# - It lacks understanding of context, emotions, and complex reasoning.
# - Real AGI would require advanced algorithms, vast datasets, and significant computational resources.
#
# This code serves as a basic starting point for understanding how conversational agents can learn from interactions. For true AGI, much more sophisticated techniques and architectures would be necessary.

# %% [markdown]
# ### Sequential chain: 2 models in single sequence

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnableLambda
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(model="gpt-5.6-luna", temperature=0)

# 1) Chain: summary (input: {text} → output: str)
summary_chain = (
    ChatPromptTemplate.from_messages([
        ("system", "Summarize the text below in 1–2 sentences."),
        ("user", "{text}")
    ])
    | llm
    | StrOutputParser()
)

# 2) Adapter: replace str → {"text": str} and pass to next prompt
to_dict = RunnableLambda(lambda s: {"text": s})

# 3) Chain: translate summary to french (input: {text} → output: str)
translate_chain = (
    ChatPromptTemplate.from_messages([
        ("system", "Translate the text into French."),
        ("user", "{text}")
    ])
    | llm
    | StrOutputParser()
)

sequential_chain = summary_chain | to_dict | translate_chain
input_text = "LangChain enables the creation of AI applications by combining models, prompts, and tools into coherent pipelines."

final_translation = sequential_chain.invoke({"text": input_text})

print(final_translation)
# Out:
# LangChain facilite le développement d'applications d'IA en intégrant des modèles, des invites et des outils dans des flux de travail structurés.

# %% [markdown]
# ### Branching chain: one response, two processing

# %%
from langchain_core.runnables import RunnableParallel

# summary prompt
prompt_summary = ChatPromptTemplate.from_template("Summarize: {text}")

# sentiment prompt
prompt_sentiment = ChatPromptTemplate.from_template("Classify sentiment: {text}")

branch_chain = RunnableParallel(
    summary=(prompt_summary | llm | StrOutputParser()),
    sentiment=(prompt_sentiment | llm | StrOutputParser())
)

text = "I am very happy with this course, I learned a lot about LangChain! Now I know that LangChain enables the creation of AI applications by combining models, prompts, and tools into coherent pipelines."
result = branch_chain.invoke({"text": text})

print(result)
